# %%
import pandas as pd
import pylab as plt
import numpy as np
import pandas.plotting as rplot
from matplotlib.ticker import NullFormatter
from mpl_toolkits.mplot3d import Axes3D

# %%
#Controlling the line properties of a chart
plt.plot([1,2,3,4], [1,4,9,16], linewidth=4.0)
plt.show()

# %%
#Using the setp()
line = plt.plot([1,2,3,4], [1,4,9,16])
plt.setp(line, color='r', linewidth=2.0) #setting the color and width of the line
plt.show()

# %%
#Creating multiple plots
p1 = np.arange(0.0, 30.0, 0.1)
plt.subplot(211)
plt.plot(p1, np.sin(p1)/p1,'b--')

plt.subplot(212)
plt.plot(p1, np.cos(p1), 'r--')
plt.show()
# Out:
# /tmp/ipykernel_2652/312601720.py:4: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(p1, np.sin(p1)/p1,'b--')

# %%
#Playing with text
n = np.random.random_sample((5,))
plt.bar(np.arange(len(n)), n)
plt.xlabel('Indices')
plt.ylabel('Value')
plt.text(1, .7, r'$\mu=' + str(np.round(np.mean(n), 2)) + '$')
plt.show()

# %%
ax = plt.subplot(111)
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)
plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5), arrowprops=dict(facecolor='black', shrink=0.05),)
plt.ylim(-2,2)
plt.show()

# %%
#Styling your plots
plt.style.use('ggplot')
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
#Styling your plots
plt.style.use('fivethirtyeight')
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
with plt.style.context(('dark_background')):
    plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
#Box Plots
#Creating Some Data
np.random.seed(10)
box_data_1 = np.random.normal(100, 10, 200)
box_data_2 = np.random.normal(80, 30, 200)
box_data_3 = np.random.normal(90, 20, 200)

#combining the different data in a list
data_to_plot = [box_data_1, box_data_2, box_data_3]

#create the boxplot
bp = plt.boxplot(data_to_plot)

# %%
## add patch_artist=True option to ax.boxplot()
## to get fill color
bp = plt.boxplot(data_to_plot, patch_artist=True)

# %%
## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    #change outline color
    box.set(color='#7570b3', linewidth=2)
    #change fill color
    box.set(facecolor='#1b9e77')

# %%
## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#7570b3', linewidth=2)

# %%
## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='#7570b3', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#b2df8a', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='#e7298a', alpha=0.5)

# %%
bp = plt.boxplot(data_to_plot, patch_artist=True)

# %%
data = np.random.rand(10,6)
rows = list('ZYXWVUTSRQ') #Ylabel
columns = list('ABCDEF') #Xlabel

# %%
plt.pcolor(data)
plt.show()

# %%
#Add Row/Column Labels
plt.pcolor(data)
plt.xticks(np.arange(0,6)+0.5, columns)
plt.yticks(np.arange(0,10)+0.5, rows)
plt.show()

# %%
# Change color map
#Add Row/Column Labels
plt.pcolor(data, cmap=plt.cm.Reds, edgecolors='k')
plt.xticks(np.arange(0,6)+0.5, columns)
plt.yticks(np.arange(0,10)+0.5, rows)
plt.show()

# %%
#Generate some test data
x = np.random.randn(8873)
y = np.random.randn(8873)

heatmap, xedges, yedges = np.histogram2d(x, y, bins=50)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
plt.imshow(heatmap, extent=extent)
plt.show()

# %%
#Scatter plots with histograms
#the random data
x = np.random.randn(1000)
y = np.random.randn(1000)
nullfmt = NullFormatter() #no labels

#definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
bottom_h = left_h = left+width+0.02

rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom_h, width, 0.2]
rect_histy = [left_h, bottom, 0.2, height]

#start with a rectangular Figure
plt.figure(1, figsize=(8,8))

axScatter = plt.axes(rect_scatter)
axHistx = plt.axes(rect_histx)
axHisty = plt.axes(rect_histy)

#no labels
axHistx.xaxis.set_major_formatter(nullfmt)
axHisty.yaxis.set_major_formatter(nullfmt)

#the scatter plot
axScatter.scatter(x, y)

#now determine nice limits by hand:
binwidth = 0.25
xymax = np.max([np.max(np.fabs(x)), np.max(np.fabs(y))])
lim = (int(xymax/binwidth) + 1) * binwidth

axScatter.set_xlim((-lim, lim))
axScatter.set_ylim((-lim, lim))

bins = np.arange(-lim, lim + binwidth, binwidth)

axHistx.hist(x, bins=bins)
axHisty.hist(y, bins=bins, orientation='horizontal')

axHistx.set_xlim(axScatter.get_xlim())
axHisty.set_ylim(axScatter.get_ylim())

plt.show()

# %%
df = pd.DataFrame(np.random.rand(1000,4), columns=['a','b','c','d'])
spm = pd.plotting.scatter_matrix(df, alpha=0.2, figsize=(6,6), diagonal='hist')

# %%
spm = pd.plotting.scatter_matrix(df, alpha=0.2, figsize=(6,6), diagonal='kde')

# %%
#Area plots
df = pd.DataFrame(np.random.rand(10,4), columns=['p','q','r','s'])
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area', stacked=False)
# Out:
# <AxesSubplot:>

# %%
#Bubble charts
plt.style.use('ggplot')
df = pd.DataFrame(np.random.rand(50,3), columns=['a','b','c'])
df.plot(kind='scatter', x='a', y='b', s=df['c']*400)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
#Hexagon bin plots
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df['b'] = df['b'] + np.arange(1000)
df.plot(kind='hexbin', x='a', y='b', gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
#Trellis plots
tips_data = pd.read_csv('tips.csv')
plt.figure()
plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomHistogram())
plot.render(plt.gcf())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2652/2412690865.py in <module>
#       2 tips_data = pd.read_csv('tips.csv')
#       3 plt.figure()
# ----> 4 plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
#       5 plot.add(rplot.TrellisGrid(['sex', 'smoker']))
#       6 plot.add(rplot.GeomHistogram())
#
# AttributeError: module 'pandas.plotting' has no attribute 'RPlot'

# %%
plt.figure()
plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomDensity())
plot.render(plt.gcf())

# %%
plt.figure()
plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomScatter())
plot.add(rplot.GeomPolyFit(degree=2))
plot.render(plt.gcf())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2652/3122608524.py in <module>
#       1 plt.figure()
# ----> 2 plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
#       3 plot.add(rplot.TrellisGrid(['sex', 'smoker']))
#       4 plot.add(rplot.GeomScatter())
#       5 plot.add(rplot.GeomPolyFit(degree=2))
#
# AttributeError: module 'pandas.plotting' has no attribute 'RPlot'

# %%
plt.figure()
plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomScatter())
plot.add(rplot.GeomDensity2D())
plot.render(plt.gcf())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2652/548336813.py in <module>
#       1 plt.figure()
# ----> 2 plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
#       3 plot.add(rplot.TrellisGrid(['sex', 'smoker']))
#       4 plot.add(rplot.GeomScatter())
#       5 plot.add(rplot.GeomDensity2D())
#
# AttributeError: module 'pandas.plotting' has no attribute 'RPlot'

# %%
#A 3D plot of a surface
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
ax.plot_surface(X,Y,Z, rstride=1, cstride=1, cmap='hot')
# Out:
# /tmp/ipykernel_2652/2524383191.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.view_init(elev=0., azim=0)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')
# Out:
# /tmp/ipykernel_2652/3842626439.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.view_init(elev=50., azim=0)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')
# Out:
# /tmp/ipykernel_2652/704907548.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.view_init(elev=50., azim=30)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')
# Out:
# /tmp/ipykernel_2652/208342559.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# Unsupervised learning
