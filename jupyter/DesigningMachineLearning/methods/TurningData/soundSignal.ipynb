# %%
import soundfile as sf
import matplotlib.pyplot as plt
import numpy as np

# %%
sig, samplerate = sf.read('file_example_WAV_2MG.wav')
sig.shape
# Out:
# (536474, 2)

# %%
slice = sig[0:2000, :]
ft = np.abs(np.fft.fft(slice))
#Finall lets plot the result
plt.plot(ft)
plt.plot(slice)
