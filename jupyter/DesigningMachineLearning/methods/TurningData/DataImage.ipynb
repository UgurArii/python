# %%
from PIL import Image
from matplotlib import pyplot as plt
import numpy as np

# %%
image = np.array(Image.open('fig-7.png'))
plt.imshow(image, interpolation='nearest')
plt.show()
print(image.shape)
# Out:
# (480, 640, 4)
