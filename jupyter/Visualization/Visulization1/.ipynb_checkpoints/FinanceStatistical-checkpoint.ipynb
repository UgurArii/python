# %% [markdown]
# Financial and Statistical Models

# %%
import matplotlib.pyplot as plt

principle_value = 10000 #invested amount
grossReturn = 1.06 #Rt

return_amt = []
x = []
y = [10000]
year = 2010
return_amt.append(principle_value)
x.append(year)

for i in range(1,15):
    return_amt.append(return_amt[i-1] * grossReturn)
    print("Year-",i,"Returned:", return_amt[i])
    
    year += 1
    x.append(year)
    y.append(833.33 * (year-2010) + principle_value)
#set the grid to apper
plt.grid()

#plot the return values curve
plt.plot(x, return_amt, color='r')
plt.plot(x,y,color='b')
# Out:
# Year- 1 Returned: 10600.0
# Year- 2 Returned: 11236.0
# Year- 3 Returned: 11910.16
# Year- 4 Returned: 12624.7696
# Year- 5 Returned: 13382.255776
# Year- 6 Returned: 14185.191122560002
# Year- 7 Returned: 15036.302589913603
# Year- 8 Returned: 15938.48074530842
# Year- 9 Returned: 16894.789590026925
# Year- 10 Returned: 17908.47696542854
# Year- 11 Returned: 18982.985583354253
# Year- 12 Returned: 20121.96471835551
# Year- 13 Returned: 21329.28260145684
# Year- 14 Returned: 22609.039557544253
