# %%
import numpy as np
import pandas as pd

# %%
nls97 = pd.read_csv("https://github.com/PacktPublishing/Python-Data-Cleaning-Cookbook/blob/master/Chapter03/data/nls97.csv?raw=true%22)nls97")

# %%
nls97
# Out:
#       personid  gender  birthmonth  birthyear  highestgradecompleted  \
# 0       100061  Female           5       1980                   13.0
# 1       100139    Male           9       1983                   12.0
# 2       100284    Male          11       1984                    7.0
# 3       100292    Male           4       1982                    NaN
# 4       100583    Male           1       1980                   13.0
# ...        ...     ...         ...        ...                    ...
# 8979    999291  Female           4       1981                   16.0
# 8980    999406    Male           7       1982                   14.0
# 8981    999543  Female           8       1984                   12.0
# 8982    999698  Female           5       1983                   12.0
# 8983    999963  Female           9       1982                   17.0
#
#       maritalstatus  childathome  childnotathome  wageincome  \
# 0           Married          4.0             0.0     12500.0
# ...

# %%
nls97[nls97["childathome"]+nls97["childnotathome"]>=7]
# Out:
#       personid  gender  birthmonth  birthyear  highestgradecompleted  \
# 322     129726  Female           7       1980                   11.0
# 399     137929  Female           5       1983                   11.0
# 409     138744    Male          11       1984                   10.0
# 479     145439  Female           2       1981                   16.0
# 627     161977  Female          10       1981                   12.0
# 693     167974  Female           1       1981                    NaN
# 720     170485    Male           1       1982                   13.0
# 1032    199083  Female           3       1982                   10.0
# 1034    199228  Female           5       1980                   12.0
# 2222    319245    Male          11       1982                   13.0
# 2668    365285  Female           2       1980                   10.0
# 2716    369449  Female          12       1980                    8.0
# 3260    423484    Male           5       1980                   11.0
# ...

# %%
nls97.wageincome.mean()
# Out:
# 49477.022196032216

# %%
nls97.wageincome.describe()
# Out:
# count      5091.000000
# mean      49477.022196
# std       40677.696798
# min           0.000000
# 25%       25000.000000
# 50%       40000.000000
# 75%       62000.000000
# max      235884.000000
# Name: wageincome, dtype: float64

# %%
nls97.wageincome.quantile(0.1)
# Out:
# 12000.0

# %%
nls97["wageincome"].quantile(np.arange(0.1,1.1,0.1))
# Out:
# 0.1     12000.0
# 0.2     21000.0
# 0.3     28000.0
# 0.4     35000.0
# 0.5     40000.0
# 0.6     48000.0
# 0.7     56000.0
# 0.8     70000.0
# 0.9     92000.0
# 1.0    235884.0
# Name: wageincome, dtype: float64

# %%
nls97.groupby(['birthyear'])['birthyear'].count()
# Out:
# birthyear
# 1980    1691
# 1981    1874
# 1982    1841
# 1983    1807
# 1984    1771
# Name: birthyear, dtype: int64

# %%
nls97.groupby(['birthmonth'])['birthmonth'].count()
# Out:
# birthmonth
# 1     816
# 2     693
# 3     760
# 4     659
# 5     689
# 6     720
# 7     762
# 8     782
# 9     839
# 10    765
# 11    763
# 12    736
# Name: birthmonth, dtype: int64

# %%
schoolRecordCols = ['satverbal','satmath','gpaoverall','gpaenglish',
  'gpamath','gpascience','highestdegree','highestgradecompleted']

demoCols = ['maritalstatus','childathome','childnotathome',
  'wageincome','weeklyhrscomputer','weeklyhrstv','nightlyhrssleep']

# %%
schoolrecord = nls97[schoolRecordCols]

# %%
schoolrecord.isnull().sum()
# Out:
# satverbal                0
# satmath                  0
# gpaoverall               0
# gpaenglish               0
# gpamath                  0
# gpascience               0
# highestdegree            0
# highestgradecompleted    0
# dtype: int64
