# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import csv

# %%
x=[]
y=[]
with open('cluster.csv','r') as csvf:
    reader = csv.reader(csvf, delimiter=',')
    for row in reader:
        x.append(row[1])
        y.append(row[2])
        
data = []
for i in range(0,120):
    data.append([x[i], y[i]])
plt.figure(figsize=(10,10))

plt.xlim(0,12)
plt.ylim(0,12)

plt.xlabel("X values",fontsize=14)
plt.ylabel("Y values", fontsize=14)
plt.title("Before Clustering ", fontsize=20)
plt.plot(x, y, 'k.', color='#0080ff', markersize=35, alpha=0.6)
kmeans = KMeans(init='k-means++', n_clusters=3, n_init=10)
kmeans.fit(data)
plt.figure(figsize=(10,10))
plt.xlabel("X values",fontsize=14)
plt.ylabel("Y values", fontsize=14)
plt.title("After K-Means Clustering (from scikit-learn)", fontsize=20)
plt.plot(x, y, 'k.', color='r', markersize=45, alpha=0.6)
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', s=200,
linewidths=3, color='b', zorder=10)
plt.show()
# Out:
# /tmp/ipykernel_1989/1362781924.py:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x, y, 'k.', color='#0080ff', markersize=35, alpha=0.6)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 22
#      20 plt.plot(x, y, 'k.', color='#0080ff', markersize=35, alpha=0.6)
#      21 kmeans = KMeans(init='k-means++', n_clusters=3, n_init=10)
# ---> 22 kmeans.fit(data)
#      23 plt.figure(figsize=(10,10))
#      24 plt.xlabel("X values",fontsize=14)
#
# File ~/tutorial-env/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1417, in KMeans.fit(self, X, y, sample_weight)
#    1390 """Compute k-means clustering.
#    1391
#    1392 Parameters
#    (...)
#    1413     Fitted estimator.
#    1414 """
#    1415 self._validate_params()
# ...
