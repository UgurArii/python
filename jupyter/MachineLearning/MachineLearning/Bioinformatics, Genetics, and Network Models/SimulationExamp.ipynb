# %%
from numpy.random import standard_normal
from numpy import zeros, sqrt
import matplotlib.pyplot as plt

# %%
S_init = 20.222
T =1
tstep =0.0002
sigma = 0.4
mu = 1
NumSimulation=6
colors = [ (214,27,31), (148,103,189), (229,109,0), (41,127,214),
(227,119,194),(44,160,44),(227,119,194), (72,17,121), (196,156,148)]
# Scale the RGB values to the [0, 1] range.
for i in range(len(colors)):
    r, g, b = colors[i]
    colors[i] = (r / 255., g / 255., b / 255.)
plt.figure(figsize=(12,12))
Steps=round(T/tstep); #Steps in years
S = zeros([NumSimulation, Steps], dtype=float)
x = range(0, int(Steps), 1)

# %%
for j in range(0, NumSimulation, 1):
    S[j,0]= S_init
    for i in x[:-1]:
        S[j,i+1]=S[j,i]+S[j,i]*(mu-0.5*pow(sigma,2))*tstep+ sigma*S[j,i]*sqrt(tstep)*standard_normal()
    plt.plot(x, S[j], linewidth=2., color=colors[j])
plt.title('%d Simulation using %d Steps, \n$\sigma$=%.6f $\mu$=%.6f$S_0$=%.6f ' % (int(NumSimulation), int(Steps), sigma, mu, S_init),
fontsize=18)
plt.xlabel('steps', fontsize=16)
plt.grid(True)
plt.ylabel('stock price', fontsize=16)
plt.ylim(0,90)
# Out:
# (0.0, 90.0)

# %%
from matplotlib import finance
import matplotlib.pyplot as plt
import statsmodels.api as sm
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from matplotlib import finance
#       2 import matplotlib.pyplot as plt
#       3 import statsmodels.api as sm
#
# ImportError: cannot import name 'finance' from 'matplotlib' (/root/tutorial-env/lib/python3.10/site-packages/matplotlib/__init__.py)

# %%
titleStr='Stock price of FB from May. 2012 to Dec. 2014'
plt.figure(figsize=(11,10))
dt1 = datetime.datetime(2012, 05, 01)
dt2 = datetime.datetime(2014, 12, 01)
sp=finance.quotes_historical_yahoo('FB',dt1,dt2,asobject=None)
plt.title(titleStr, fontsize=16)
plt.xlabel("Days", fontsize=14)
plt.ylabel("Stock Price", fontsize=14)
xfilter = sm.tsa.filters.hpfilter(sp[:,2], lamb=100000)[1]
plt.plot(sp[:,2])
plt.hold(True)
plt.plot(xfilter,linewidth=5.)
# Out:
#   Cell In[9], line 3
#     dt1 = datetime.datetime(2012, 05, 01)
#                                   ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
import matplotlib.pyplot as plt
from numpy import concatenate, zeros, ones, hamming, convolve
digital = concatenate ( (zeros(20), ones(25), zeros(20)))
norm_hamming = hamming(80)/sum(hamming(80))
res = convolve(digital, norm_hamming)
plt.figure(figsize=(10,10))
plt.ylim(0, 0.6)
plt.plot(res, color='r', linewidth=2)
plt.hold(True)
plt.plot(data, color='b', linewidth=3)
plt.hold(True)
plt.plot(norm_hamming, color='g', linewidth=4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 9
#       7 plt.ylim(0, 0.6)
#       8 plt.plot(res, color='r', linewidth=2)
# ----> 9 plt.hold(True)
#      10 plt.plot(data, color='b', linewidth=3)
#      11 plt.hold(True)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'hold'

# %%
import matplotlib.pyplot as plt
from scipy import randn
from numpy import fft
plt.figure(figsize=(10,10))
random_data = randn(500)
res = fft.fft(random_data)
plt.plot(res, color='b')
plt.hold(True)
plt.plot(random_data, color='r')
plt.show()
# Out:
# /tmp/ipykernel_15247/13058312.py:5: DeprecationWarning: scipy.randn is deprecated and will be removed in SciPy 2.0.0, use numpy.random.randn instead
#   random_data = randn(500)
# /root/tutorial-env/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 8
#       6 res = fft.fft(random_data)
#       7 plt.plot(res, color='b')
# ----> 8 plt.hold(True)
#       9 plt.plot(random_data, color='r')
#      10 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'hold'

# %%
import scipy.misc as scm
from scipy.misc.pilutil import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 import scipy.misc as scm
# ----> 2 from scipy.misc.pilutil import Image
#
# ModuleNotFoundError: No module named 'scipy.misc.pilutil'

# %%
# open original image
orig_image = Image.open('filter.jpg')
# extract image data into array
image1 = scm.fromimage(orig_image)
# invert array values
inv_image = 255 - image1
# using inverted array values, convert image
inverted_image = scm.toimage(inv_image)
#save inverted image
inverted_image.save('filter_invert.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # open original image
# ----> 2 orig_image = Image.open('filter.jpg')
#       3 # extract image data into array
#       4 image1 = scm.fromimage(orig_image)
#
# NameError: name 'Image' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation

# %%
# Set up the figure, axis, and the plot element to be animated
fig = plt.figure()
ax = plt.axes(xlim=(0, 3.2), ylim=(-2.14, 2.14))
line, = ax.plot([], [], lw=2)

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line

# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    xval = 2 * np.pi * (x - 0.01 * i)
    y = np.cos(xval) # Here we are trying to animate cos function
    line.set_data(x, y)
    return line

anim = animation.FuncAnimation(fig, animate, init_func=init,frames=200, interval=20, blit=True)
anim.save('basic_animation.mp4', fps=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 14
#      11     line.set_data(x, y)
#      12     return line
# ---> 14 anim = animation.FuncAnimation(fig, animate, init_func=init,
#      15 frames=200, interval=20, blit=True)
#      16 anim.save('basic_animation.mp4', fps=30)
#      17 plt.show()
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/animation.py:1659, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1656 # Needs to be initialized so the draw functions work without checking
#    1657 self._save_seq = []
# -> 1659 super().__init__(fig, **kwargs)
#    1661 # Need to reset the saved seq, since right now it will contain data
#    1662 # for a single frame from init, which is not what we want.
#    1663 self._save_seq = []
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/animation.py:1394, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1392 if event_source is None:
#    1393     event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1394 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/animation.py:875, in Animation.__init__(self, fig, event_source, blit)
#     872 self._close_id = self._fig.canvas.mpl_connect('close_event',
#     873                                               self._stop)
#     874 if self._blit:
# --> 875     self._setup_blit()
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/animation.py:1187, in Animation._setup_blit(self)
#    1185 self._drawn_artists = []
#    1186 # _post_draw needs to be called first to initialize the renderer
# -> 1187 self._post_draw(None, self._blit)
#    1188 # Then we need to clear the Frame for the initial draw
#    1189 # This is typically handled in _on_resize because QT and Tk
#    1190 # emit a resize event on launch, but the macosx backend does not,
#    1191 # thus we force it here for everyone for consistency
#    1192 self._init_draw()
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/animation.py:1142, in Animation._post_draw(self, framedata, blit)
#    1140     self._blit_draw(self._drawn_artists)
#    1141 else:
# -> 1142     self._fig.canvas.draw_idle()
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2052 if not self._is_idle_drawing:
#    2053     with self._idle_draw_cntx():
# -> 2054         self.draw(*args, **kwargs)
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/figure.py:3081, in Figure.draw(self, renderer)
#    3078 finally:
#    3079     self.stale = False
# -> 3081 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/backend_bases.py:1230, in Event._process(self)
#    1228 def _process(self):
#    1229     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1230     self.canvas.callbacks.process(self.name, self)
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:312, in CallbackRegistry.process(self, s, *args, **kwargs)
#     310 except Exception as exc:
#     311     if self.exception_handler is not None:
# --> 312         self.exception_handler(exc)
#     313     else:
#     314         raise
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:307, in CallbackRegistry.process(self, s, *args, **kwargs)
#     305 if func is not None:
#     306     try:
# --> 307         func(*args, **kwargs)
#     308     # this does not capture KeyboardInterrupt, SystemExit,
#     309     # and GeneratorExit
#     310     except Exception as exc:
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/animation.py:899, in Animation._start(self, *args)
#     896 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     898 # Now do any initial draw
# --> 899 self._init_draw()
#     901 # Add our callback for stepping the animation and
#     902 # actually start the event_source.
#     903 self.event_source.add_callback(self._step)
#
# File ~/tutorial-env/lib/python3.10/site-packages/matplotlib/animation.py:1728, in FuncAnimation._init_draw(self)
#    1725         if self._drawn_artists is None:
#    1726             raise RuntimeError('The init_func must return a '
#    1727                                'sequence of Artist objects.')
# -> 1728         for a in self._drawn_artists:
#    1729             a.set_animated(self._blit)
#    1730 self._save_seq = []
#
# TypeError: 'Line2D' object is not iterable
